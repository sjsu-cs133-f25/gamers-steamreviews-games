# %% [markdown]
# # Data Exploration of the Steam Dataset
#
# Please download the dataset at the following link and assign the csv path below:
#
# https://www.gigasheet.com/sample-data/steam-game-reviews

# %% [markdown]
# ## 1 - Setup

# %% [markdown]
# ### 1.1 Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1.2 Load Datasets

# %% [markdown]
# Steam Reviews dataset

# %%
reviews_path = '../data/Steam Game Reviews export 2025-09-03 01-50-49.csv' # Replace with the path to your reviews CSV File
game_metadata_path = '../data/games_description.csv' # Replace with path to game metadata CSV file


steamreviews = pd.read_csv(reviews_path)
gamemetadata = pd.read_csv(game_metadata_path)
steamreviews.head()
# Out:
#                                               review  hours_played  helpful  \
# 0  The game itself is also super fun. The PvP and...          39.9     1152
# 1  Never cared much about Warhammer until this ga...          91.5      712
# 2  A salute to all the fallen battle brothers who...          43.3      492
# 3  this game feels like it was made in the mid 20...          16.8      661
# 4  Reminds me of something I've lost. A genuine g...          24.0      557
#
#    funny recommendation          date                         game_name  \
# 0     13    Recommended  14 September  Warhammer 40,000: Space Marine 2
# 1    116    Recommended  13 September  Warhammer 40,000: Space Marine 2
# 2     33    Recommended  14 September  Warhammer 40,000: Space Marine 2
# 3     15    Recommended  14 September  Warhammer 40,000: Space Marine 2
# 4      4    Recommended  12 September  Warhammer 40,000: Space Marine 2
#
#                              username
# 0  Sentinowl\n224 products in account
# 1    userpig\n248 products in account
# 2  Imparat0r\n112 products in account
# 3                      Fattest_falcon
# 4        Jek\n410 products in account

# %%
gamemetadata.head()
# Out:
#                                name  \
# 0                Black Myth: Wukong
# 1                  Counter-Strike 2
# 2  Warhammer 40,000: Space Marine 2
# 3                    Cyberpunk 2077
# 4                        ELDEN RING
#
#                                    short_description  \
# 0  Black Myth: Wukong is an action RPG rooted in ...
# 1  For over two decades, Counter-Strike has offer...
# 2  Embody the superhuman skill and brutality of a...
# 3  Cyberpunk 2077 is an open-world, action-advent...
# 4  THE CRITICALLY ACCLAIMED FANTASY ACTION RPG. R...
#
#                                     long_description  \
# 0  About This Game\n\t\t\t\t\t\t\tBlack Myth: Wuk...
# 1  About This Game\n\t\t\t\t\t\t\tFor over two de...
# 2  About This Game\nEmbody the superhuman skill a...
# 3  About This Game\nCyberpunk 2077 is an open-wor...
# 4  About This Game\nTHE CRITICALLY ACCLAIMED FANT...
#
#                                               genres  \
# 0  ['Mythology', 'Action RPG', 'Action', 'RPG', '...
# 1  ['FPS', 'Shooter', 'Multiplayer', 'Competitive...
# 2  ['Warhammer 40K', 'Action', 'Third-Person Shoo...
# 3  ['Cyberpunk', 'Open World', 'Nudity', 'RPG', '...
# 4  ['Souls-like', 'Dark Fantasy', 'Open World', '...
#
#                           minimum_system_requirement  \
# 0  ['Requires a 64-bit processor and operating sy...
# 1  ['OS: Windows® 10', 'Processor: 4 hardware CPU...
# 2  ['Requires a 64-bit processor and operating sy...
# 3  ['Requires a 64-bit processor and operating sy...
# 4  ['Requires a 64-bit processor and operating sy...
#
#                         recommend_system_requirement  release_date  \
# 0  ['Requires a 64-bit processor and operating sy...  19 Aug, 2024
# 1  ['OS: Windows® 10', 'Processor: 4 hardware CPU...  21 Aug, 2012
# 2  ['Requires a 64-bit processor and operating sy...   9 Sep, 2024
# 3  ['Requires a 64-bit processor and operating sy...  10 Dec, 2020
# 4  ['Requires a 64-bit processor and operating sy...  25 Feb, 2022
#
#                 developer                                          publisher  \
# 0        ['Game Science']                                   ['Game Science']
# 1               ['Valve']                                          ['Valve']
# 2   ['Saber Interactive']                            ['Focus Entertainment']
# 3      ['CD PROJEKT RED']                                 ['CD PROJEKT RED']
# 4  ['FromSoftware, Inc.']  ['FromSoftware, Inc.', 'Bandai Namco Entertain...
#
#      overall_player_rating number_of_reviews_from_purchased_people  \
# 0  Overwhelmingly Positive                               (654,820)
# 1            Very Positive                             (8,313,603)
# 2            Very Positive                (81% of 62,791) All Time
# 3            Very Positive                               (680,264)
# 4            Very Positive                               (705,261)
#
#   number_of_english_reviews                                               link
# 0                    51,931  https://store.steampowered.com/app/2358720/Bla...
# 1                 2,258,990  https://store.steampowered.com/app/730/Counter...
# 2                    51,920  https://store.steampowered.com/app/2183900/War...
# 3                   324,124  https://store.steampowered.com/app/1091500/Cyb...
# 4                   491,741  https://store.steampowered.com/app/1245620/ELD...

# %% [markdown]
# ### 1.3 Merge Datasets

# %%
steamdataset = pd.merge(steamreviews, gamemetadata, left_on='game_name', right_on='name', how='left')
steamdataset.drop(columns=['name'], inplace=True)
steamdataset
# Out:
#                                                    review  hours_played  \
# 0       The game itself is also super fun. The PvP and...          39.9
# 1       Never cared much about Warhammer until this ga...          91.5
# 2       A salute to all the fallen battle brothers who...          43.3
# 3       this game feels like it was made in the mid 20...          16.8
# 4       Reminds me of something I've lost. A genuine g...          24.0
# ...                                                   ...           ...
# 992148  2022 Early Access Review Loads of fun!Initiall...           4.2
# 992149                2022 Early Access Review Great fun!           8.5
# 992150  2022 Early Access Review Excellent pick up and...          83.3
# 992151  2022 Early Access Review This game is so much ...           3.8
# 992152  2022 Early Access Review Im in love with the G...         315.3
#
#         helpful  funny   recommendation            date  \
# 0          1152     13      Recommended    14 September
# 1           712    116      Recommended    13 September
# 2           492     33      Recommended    14 September
# 3           661     15      Recommended    14 September
# 4           557      4      Recommended    12 September
# ...         ...    ...              ...             ...
# 992148        1      0      Recommended  August 4, 2022
# 992149        1      0      Recommended  August 4, 2022
# 992150        2      0      Recommended  August 4, 2022
# 992151        1      0      Recommended  August 4, 2022
# 992152        0      0  Not Recommended  August 4, 2022
#
#                                game_name  \
# 0       Warhammer 40,000: Space Marine 2
# 1       Warhammer 40,000: Space Marine 2
# 2       Warhammer 40,000: Space Marine 2
# 3       Warhammer 40,000: Space Marine 2
# 4       Warhammer 40,000: Space Marine 2
# ...                                  ...
# 992148                 Turbo Golf Racing
# 992149                 Turbo Golf Racing
# 992150                 Turbo Golf Racing
# 992151                 Turbo Golf Racing
# 992152                 Turbo Golf Racing
#
#                                      username  \
# 0          Sentinowl\n224 products in account
# 1            userpig\n248 products in account
# 2          Imparat0r\n112 products in account
# 3                              Fattest_falcon
# 4                Jek\n410 products in account
# ...                                       ...
# 992148  Fatal Exit\n1,902 products in account
# 992149                                cleybaR
# 992150           Sim\n600 products in account
# 992151                           Fatboybadboy
# 992152         Wolfy\n136 products in account
#
#                                         short_description  \
# 0       Embody the superhuman skill and brutality of a...
# 1       Embody the superhuman skill and brutality of a...
# 2       Embody the superhuman skill and brutality of a...
# 3       Embody the superhuman skill and brutality of a...
# 4       Embody the superhuman skill and brutality of a...
# ...                                                   ...
# 992148                                                NaN
# 992149                                                NaN
# 992150                                                NaN
# 992151                                                NaN
# 992152                                                NaN
#
#                                          long_description  \
# 0       About This Game\nEmbody the superhuman skill a...
# 1       About This Game\nEmbody the superhuman skill a...
# 2       About This Game\nEmbody the superhuman skill a...
# 3       About This Game\nEmbody the superhuman skill a...
# 4       About This Game\nEmbody the superhuman skill a...
# ...                                                   ...
# 992148                                                NaN
# 992149                                                NaN
# 992150                                                NaN
# 992151                                                NaN
# 992152                                                NaN
#
#                                                    genres  \
# 0       ['Warhammer 40K', 'Action', 'Third-Person Shoo...
# 1       ['Warhammer 40K', 'Action', 'Third-Person Shoo...
# 2       ['Warhammer 40K', 'Action', 'Third-Person Shoo...
# 3       ['Warhammer 40K', 'Action', 'Third-Person Shoo...
# 4       ['Warhammer 40K', 'Action', 'Third-Person Shoo...
# ...                                                   ...
# 992148                                                NaN
# 992149                                                NaN
# 992150                                                NaN
# 992151                                                NaN
# 992152                                                NaN
#
#                                minimum_system_requirement  \
# 0       ['Requires a 64-bit processor and operating sy...
# 1       ['Requires a 64-bit processor and operating sy...
# 2       ['Requires a 64-bit processor and operating sy...
# 3       ['Requires a 64-bit processor and operating sy...
# 4       ['Requires a 64-bit processor and operating sy...
# ...                                                   ...
# 992148                                                NaN
# 992149                                                NaN
# 992150                                                NaN
# 992151                                                NaN
# 992152                                                NaN
#
#                              recommend_system_requirement release_date  \
# 0       ['Requires a 64-bit processor and operating sy...  9 Sep, 2024
# 1       ['Requires a 64-bit processor and operating sy...  9 Sep, 2024
# 2       ['Requires a 64-bit processor and operating sy...  9 Sep, 2024
# 3       ['Requires a 64-bit processor and operating sy...  9 Sep, 2024
# 4       ['Requires a 64-bit processor and operating sy...  9 Sep, 2024
# ...                                                   ...          ...
# 992148                                                NaN          NaN
# 992149                                                NaN          NaN
# 992150                                                NaN          NaN
# 992151                                                NaN          NaN
# 992152                                                NaN          NaN
#
#                     developer                publisher overall_player_rating  \
# 0       ['Saber Interactive']  ['Focus Entertainment']         Very Positive
# 1       ['Saber Interactive']  ['Focus Entertainment']         Very Positive
# 2       ['Saber Interactive']  ['Focus Entertainment']         Very Positive
# 3       ['Saber Interactive']  ['Focus Entertainment']         Very Positive
# 4       ['Saber Interactive']  ['Focus Entertainment']         Very Positive
# ...                       ...                      ...                   ...
# 992148                    NaN                      NaN                   NaN
# 992149                    NaN                      NaN                   NaN
# 992150                    NaN                      NaN                   NaN
# 992151                    NaN                      NaN                   NaN
# 992152                    NaN                      NaN                   NaN
#
#        number_of_reviews_from_purchased_people number_of_english_reviews  \
# 0                     (81% of 62,791) All Time                    51,920
# 1                     (81% of 62,791) All Time                    51,920
# 2                     (81% of 62,791) All Time                    51,920
# 3                     (81% of 62,791) All Time                    51,920
# 4                     (81% of 62,791) All Time                    51,920
# ...                                        ...                       ...
# 992148                                     NaN                       NaN
# 992149                                     NaN                       NaN
# 992150                                     NaN                       NaN
# 992151                                     NaN                       NaN
# 992152                                     NaN                       NaN
#
#                                                      link
# 0       https://store.steampowered.com/app/2183900/War...
# 1       https://store.steampowered.com/app/2183900/War...
# 2       https://store.steampowered.com/app/2183900/War...
# 3       https://store.steampowered.com/app/2183900/War...
# 4       https://store.steampowered.com/app/2183900/War...
# ...                                                   ...
# 992148                                                NaN
# 992149                                                NaN
# 992150                                                NaN
# 992151                                                NaN
# 992152                                                NaN
#
# [992153 rows x 20 columns]

# %%
steamdataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 992153 entries, 0 to 992152
# Data columns (total 20 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   review                                   991650 non-null  object
#  1   hours_played                             992153 non-null  float64
#  2   helpful                                  992153 non-null  int64
#  3   funny                                    992153 non-null  int64
#  4   recommendation                           992153 non-null  object
#  5   date                                     992153 non-null  object
#  6   game_name                                992153 non-null  object
#  7   username                                 992072 non-null  object
#  8   short_description                        925244 non-null  object
#  9   long_description                         925244 non-null  object
#  10  genres                                   925244 non-null  object
#  11  minimum_system_requirement               925244 non-null  object
#  12  recommend_system_requirement             925244 non-null  object
#  13  release_date                             925244 non-null  object
#  14  developer                                925244 non-null  object
#  15  publisher                                925244 non-null  object
#  16  overall_player_rating                    925244 non-null  object
#  17  number_of_reviews_from_purchased_people  925244 non-null  object
#  18  number_of_english_reviews                925244 non-null  object
#  19  link                                     925244 non-null  object
# dtypes: float64(1), int64(2), object(17)
# memory usage: 151.4+ MB

# %% [markdown]
# ### 1.4 Clean up data

# %%
steamdataset[steamdataset['date'].isna()].game_name.value_counts()
# Out:
# game_name
# Supermarket Simulator                                 5010
# Palworld                                              5010
# Manor Lords                                           5010
# The First Descendant                                  5006
# Fields of Mistria                                     5000
#                                                       ...
# Shawarma Legend                                         30
# Monster Energy Supercross - The Official Videogame      29
# MXGP 2019 - The Official Motocross Videogame            20
# 69 Balls                                                19
# MXGP - The Official Motocross Videogame                  4
# Name: count, Length: 242, dtype: int64

# %% [markdown]
# Why are these missing values?? There are 14 games with missing values, we can fill them in later.

# %%
steamdataset[steamdataset['short_description'].isna()]['game_name'].unique()
# Out:
# array(['Raft', 'Stray', 'Dead Cells', "Don't Starve Together",
#        'Ori and the Will of the Wisps', 'Life is Strange - Episode 1',
#        'Human Fall Flat', "It Takes Two Friend's Pass", "Don't Starve",
#        'It Takes Two', 'NieR:Automata™', 'PAYDAY 3', 'GUNDAM BREAKER 4',
#        'Caves of Qud', 'Turbo Golf Racing'], dtype=object)

# %%
steamdataset[steamdataset['release_date'].isna()]['game_name'].unique()
# Out:
# array(['Raft', 'Stray', 'Dead Cells', "Don't Starve Together",
#        'Ori and the Will of the Wisps', 'Life is Strange - Episode 1',
#        'Human Fall Flat', "It Takes Two Friend's Pass", "Don't Starve",
#        'It Takes Two', 'NieR:Automata™', 'PAYDAY 3', 'GUNDAM BREAKER 4',
#        'Caves of Qud', 'Turbo Golf Racing'], dtype=object)

# %%
steamdataset[steamdataset['link'].isna()]['game_name'].unique()
# Out:
# array(['Raft', 'Stray', 'Dead Cells', "Don't Starve Together",
#        'Ori and the Will of the Wisps', 'Life is Strange - Episode 1',
#        'Human Fall Flat', "It Takes Two Friend's Pass", "Don't Starve",
#        'It Takes Two', 'NieR:Automata™', 'PAYDAY 3', 'GUNDAM BREAKER 4',
#        'Caves of Qud', 'Turbo Golf Racing'], dtype=object)

# %%
# TODO FILL IN MISSING METADATA, CAN BE DONE MANUALLY AT https://steamdb.info/ SEARCH FOR EACH GAME AND FILL IN

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# Let's look at the data and what we can work with for now.

# %% [markdown]
# TODO - username is a little messed up or missing for some of them, a few NaN values game descriptions, perhaps they weren't included in the secondary dataset, 11 games can be filled in manually. Can check some stuff with these

# %%
steamdataset.release_date = pd.to_datetime(steamdataset['release_date'], errors='coerce')

# %%
steamdataset.release_date
# Out:
# 0        2024-09-09
# 1        2024-09-09
# 2        2024-09-09
# 3        2024-09-09
# 4        2024-09-09
#             ...
# 992148          NaT
# 992149          NaT
# 992150          NaT
# 992151          NaT
# 992152          NaT
# Name: release_date, Length: 991650, dtype: datetime64[ns]

# %% [markdown]
# TODO - When removing nans, we lose all these games, we need to fill in the correct review year for all the data.

# %%
diff = list(set(steamdataset['game_name']) - set(steamdsnonan['game_name']))
diff
# Out:
# ['Dead Rising Deluxe Remaster',
#  'LOCKDOWN Protocol',
#  'EA SPORTS FC™ 25',
#  'Crime Scene Cleaner',
#  'Dark and Darker',
#  'EA SPORTS™ Madden NFL 25',
#  'Chained Together',
#  'GUNDAM BREAKER 4',
#  'Fields of Mistria',
#  'F1® 24',
#  'UFO 50',
#  'WWE 2K24',
#  'Age of Mythology: Retold',
#  'Once Human',
#  'Palworld',
#  'Warhammer 40,000: Space Marine 2',
#  'Shawarma Legend',
#  'Visions of Mana',
#  'Rooftops & Alleys: The Parkour Game',
#  'TCG Card Shop Simulator',
#  "Dragon's Dogma 2",
#  'Balatro',
#  'shapez 2',
#  'Dale & Dawson Stationery Supplies',
#  'Train Sim World® 5',
#  'The Crew Motorfest',
#  'The First Descendant',
#  'Black Myth: Wukong',
#  'F1® Manager 2024',
#  'Sins of a Solar Empire II',
#  'CarX Street',
#  'NBA 2K25',
#  'Manor Lords',
#  'Supermarket Simulator',
#  'Motordoom',
#  'Ale & Tale Tavern',
#  'Summoners War']

# %% [markdown]
# Note large dip in 2024 Could be an indication of where missing review information is coming from. Check reviews that have NaT to steam review dates. See if there is an issue there,

# %%
monthly_counts = steamdataset.groupby(steamdataset['release_date'].dt.to_period('M')).size()
monthly_counts.index = monthly_counts.index.to_timestamp()
monthly_counts.plot(kind='line', title='Number of Steam Reviews Over Time', xlabel='Year', ylabel='Number of Reviews')
# Out:
# <Axes: title={'center': 'Number of Steam Reviews Over Time'}, xlabel='Year', ylabel='Number of Reviews'>

# %% [markdown]
# Notable lack of review data from the year >2024, missing review date games all released in 2024 as well.

# %%
monthly_counts = steamdsnonan.resample('Y', on='date').size()
monthly_counts.plot(kind='bar', figsize=(10, 3))
# Out:
# /var/folders/h6/nnzy69c13sn43ypbbpk2877m0000gn/T/ipykernel_77244/1279311225.py:1: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   monthly_counts = steamdsnonan.resample('Y', on='date').size()
# <Axes: xlabel='date'>

# %% [markdown]
# No games release in 2024

# %%
steamdataset.groupby(steamdataset['release_date'].dt.year).game_name.nunique()
# Out:
# release_date
# 2006.0     2
# 2007.0     1
# 2009.0     2
# 2010.0     2
# 2011.0     3
# 2012.0     2
# 2013.0     9
# 2014.0     5
# 2015.0    12
# 2016.0    12
# 2017.0    13
# 2018.0    22
# 2019.0    14
# 2020.0    14
# 2021.0    19
# 2022.0    20
# 2023.0    32
# 2024.0    41
# Name: game_name, dtype: int64

# %% [markdown]
# ## B. Transformations

# %% [markdown]
# ### Missing Data Fixing

# %%
# A few dates are missing the year, highly likely that the missing year is 2024. When collecting data, Steam shows recent reviews WITHOUT the year.
def fixDates(date): 
    try:
        parts = date.split(' ')
        if len(parts) == 3:  
            # Already in format like "September 12, 2020"
            return date
        elif len(parts) == 2:
            # Format "12 September" → reorder → "September 12, 2024"
            if parts[0].isnumeric():
                day, month = parts
            else:
                month, day = parts
            fixed = f"{month} {day}, 2024"
            return fixed
        else:
            return pd.NA
    except Exception:
        return pd.NA

# %% [markdown]
# #### Series.map + date fixing

# %%
# Removing empty reviews, no text in the review column means no review information to analyize
steamdataset = steamdataset.dropna(subset=['review']).copy() # Need to use copy to avoid SettingWithCopyWarning
steamdataset['date'] = steamdataset['date'].map(fixDates)
steamdataset['date'] = pd.to_datetime(steamdataset['date'], errors='coerce')
steamdataset
# Out:
#                                                    review  hours_played  \
# 0       The game itself is also super fun. The PvP and...          39.9
# 1       Never cared much about Warhammer until this ga...          91.5
# 2       A salute to all the fallen battle brothers who...          43.3
# 3       this game feels like it was made in the mid 20...          16.8
# 4       Reminds me of something I've lost. A genuine g...          24.0
# ...                                                   ...           ...
# 992148  2022 Early Access Review Loads of fun!Initiall...           4.2
# 992149                2022 Early Access Review Great fun!           8.5
# 992150  2022 Early Access Review Excellent pick up and...          83.3
# 992151  2022 Early Access Review This game is so much ...           3.8
# 992152  2022 Early Access Review Im in love with the G...         315.3
#
#         helpful  funny   recommendation       date  \
# 0          1152     13      Recommended 2024-09-14
# 1           712    116      Recommended 2024-09-13
# 2           492     33      Recommended 2024-09-14
# 3           661     15      Recommended 2024-09-14
# 4           557      4      Recommended 2024-09-12
# ...         ...    ...              ...        ...
# 992148        1      0      Recommended 2022-08-04
# 992149        1      0      Recommended 2022-08-04
# 992150        2      0      Recommended 2022-08-04
# 992151        1      0      Recommended 2022-08-04
# 992152        0      0  Not Recommended 2022-08-04
#
#                                game_name  \
# 0       Warhammer 40,000: Space Marine 2
# 1       Warhammer 40,000: Space Marine 2
# 2       Warhammer 40,000: Space Marine 2
# 3       Warhammer 40,000: Space Marine 2
# 4       Warhammer 40,000: Space Marine 2
# ...                                  ...
# 992148                 Turbo Golf Racing
# 992149                 Turbo Golf Racing
# 992150                 Turbo Golf Racing
# 992151                 Turbo Golf Racing
# 992152                 Turbo Golf Racing
#
#                                      username  \
# 0          Sentinowl\n224 products in account
# 1            userpig\n248 products in account
# 2          Imparat0r\n112 products in account
# 3                              Fattest_falcon
# 4                Jek\n410 products in account
# ...                                       ...
# 992148  Fatal Exit\n1,902 products in account
# 992149                                cleybaR
# 992150           Sim\n600 products in account
# 992151                           Fatboybadboy
# 992152         Wolfy\n136 products in account
#
#                                         short_description  \
# 0       Embody the superhuman skill and brutality of a...
# 1       Embody the superhuman skill and brutality of a...
# 2       Embody the superhuman skill and brutality of a...
# 3       Embody the superhuman skill and brutality of a...
# 4       Embody the superhuman skill and brutality of a...
# ...                                                   ...
# 992148                                                NaN
# 992149                                                NaN
# 992150                                                NaN
# 992151                                                NaN
# 992152                                                NaN
#
#                                          long_description  \
# 0       About This Game\nEmbody the superhuman skill a...
# 1       About This Game\nEmbody the superhuman skill a...
# 2       About This Game\nEmbody the superhuman skill a...
# 3       About This Game\nEmbody the superhuman skill a...
# 4       About This Game\nEmbody the superhuman skill a...
# ...                                                   ...
# 992148                                                NaN
# 992149                                                NaN
# 992150                                                NaN
# 992151                                                NaN
# 992152                                                NaN
#
#                                                    genres  \
# 0       ['Warhammer 40K', 'Action', 'Third-Person Shoo...
# 1       ['Warhammer 40K', 'Action', 'Third-Person Shoo...
# 2       ['Warhammer 40K', 'Action', 'Third-Person Shoo...
# 3       ['Warhammer 40K', 'Action', 'Third-Person Shoo...
# 4       ['Warhammer 40K', 'Action', 'Third-Person Shoo...
# ...                                                   ...
# 992148                                                NaN
# 992149                                                NaN
# 992150                                                NaN
# 992151                                                NaN
# 992152                                                NaN
#
#                                minimum_system_requirement  \
# 0       ['Requires a 64-bit processor and operating sy...
# 1       ['Requires a 64-bit processor and operating sy...
# 2       ['Requires a 64-bit processor and operating sy...
# 3       ['Requires a 64-bit processor and operating sy...
# 4       ['Requires a 64-bit processor and operating sy...
# ...                                                   ...
# 992148                                                NaN
# 992149                                                NaN
# 992150                                                NaN
# 992151                                                NaN
# 992152                                                NaN
#
#                              recommend_system_requirement release_date  \
# 0       ['Requires a 64-bit processor and operating sy...  9 Sep, 2024
# 1       ['Requires a 64-bit processor and operating sy...  9 Sep, 2024
# 2       ['Requires a 64-bit processor and operating sy...  9 Sep, 2024
# 3       ['Requires a 64-bit processor and operating sy...  9 Sep, 2024
# 4       ['Requires a 64-bit processor and operating sy...  9 Sep, 2024
# ...                                                   ...          ...
# 992148                                                NaN          NaN
# 992149                                                NaN          NaN
# 992150                                                NaN          NaN
# 992151                                                NaN          NaN
# 992152                                                NaN          NaN
#
#                     developer                publisher overall_player_rating  \
# 0       ['Saber Interactive']  ['Focus Entertainment']         Very Positive
# 1       ['Saber Interactive']  ['Focus Entertainment']         Very Positive
# 2       ['Saber Interactive']  ['Focus Entertainment']         Very Positive
# 3       ['Saber Interactive']  ['Focus Entertainment']         Very Positive
# 4       ['Saber Interactive']  ['Focus Entertainment']         Very Positive
# ...                       ...                      ...                   ...
# 992148                    NaN                      NaN                   NaN
# 992149                    NaN                      NaN                   NaN
# 992150                    NaN                      NaN                   NaN
# 992151                    NaN                      NaN                   NaN
# 992152                    NaN                      NaN                   NaN
#
#        number_of_reviews_from_purchased_people number_of_english_reviews  \
# 0                     (81% of 62,791) All Time                    51,920
# 1                     (81% of 62,791) All Time                    51,920
# 2                     (81% of 62,791) All Time                    51,920
# 3                     (81% of 62,791) All Time                    51,920
# 4                     (81% of 62,791) All Time                    51,920
# ...                                        ...                       ...
# 992148                                     NaN                       NaN
# 992149                                     NaN                       NaN
# 992150                                     NaN                       NaN
# 992151                                     NaN                       NaN
# 992152                                     NaN                       NaN
#
#                                                      link
# 0       https://store.steampowered.com/app/2183900/War...
# 1       https://store.steampowered.com/app/2183900/War...
# 2       https://store.steampowered.com/app/2183900/War...
# 3       https://store.steampowered.com/app/2183900/War...
# 4       https://store.steampowered.com/app/2183900/War...
# ...                                                   ...
# 992148                                                NaN
# 992149                                                NaN
# 992150                                                NaN
# 992151                                                NaN
# 992152                                                NaN
#
# [991650 rows x 20 columns]

# %%
steamdataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 991650 entries, 0 to 992152
# Data columns (total 20 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   review                                   991650 non-null  object
#  1   hours_played                             991650 non-null  float64
#  2   helpful                                  991650 non-null  int64
#  3   funny                                    991650 non-null  int64
#  4   recommendation                           991650 non-null  object
#  5   date                                     989875 non-null  datetime64[ns]
#  6   game_name                                991650 non-null  object
#  7   username                                 991569 non-null  object
#  8   short_description                        924758 non-null  object
#  9   long_description                         924758 non-null  object
#  10  genres                                   924758 non-null  object
#  11  minimum_system_requirement               924758 non-null  object
#  12  recommend_system_requirement             924758 non-null  object
#  13  release_date                             924758 non-null  object
#  14  developer                                924758 non-null  object
#  15  publisher                                924758 non-null  object
#  16  overall_player_rating                    924758 non-null  object
#  17  number_of_reviews_from_purchased_people  924758 non-null  object
#  18  number_of_english_reviews                924758 non-null  object
#  19  link                                     924758 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(16)
# memory usage: 158.9+ MB

# %% [markdown]
# ### Vectorized Boolean Mask

# %%
# TODO We can possibly use the hours played or funny or helpful votes to create categorial columns, like oh this has more than some number of hours played, this is a player who played a lot of this game, or this is a funny review, etc.

steamdataset['popular'] = steamdataset['helpful'] > 100
steamdataset['popular'].value_counts()
# Out:
# popular
# False    952829
# True      38821
# Name: count, dtype: int64

# %%
# TODO can use map or apply to fix usernames with some function fixUsernames.

# %% [markdown]
# ## C. Grouping And Sorting

# %%
# TODO A few group by options. By release or review year, game name, recommended, any new categorical columns made, overall rating... 
# Check word counts on popular reviews
print(steamdataset.groupby('popular').review.apply(lambda x: x.str.split(" ").str.len().mean()))
print("Average word count between popular and not popular reviews show that popular reviews are longer on average. By over double.")
# Out:
# popular
# False     65.545717
# True     147.347312
# Name: review, dtype: float64
# Average word count between popular and not popular reviews show that popular reviews are longer on average. By over double.

# %% [markdown]
# ## D. Visuals

# %%
monthly_counts = steamdataset.groupby(steamdataset['date'].dt.to_period('M')).size()
monthly_counts.index = monthly_counts.index.to_timestamp()
monthly_counts.plot(kind='line', title='Number of Steam Reviews Over Time', xlabel='Year', ylabel='Number of Reviews')
# Out:
# <Axes: title={'center': 'Number of Steam Reviews Over Time'}, xlabel='Year', ylabel='Number of Reviews'>

# %%
# TODO Properly organize the notebook with markdowns like explained in the slides, like A. Data Card, B. Transformations,

# %%
# TODO Need to create a script for downloading data maybe? Instructions are included but perhaps a script would be more convenient.
